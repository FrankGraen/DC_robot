# %%
# %matplotlib tk

# %%
from roboticstoolbox import *
from spatialmath import *
from math import pi
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from roboticstoolbox import *
#       2 from spatialmath import *
#       3 from math import pi
#
# File e:\ProgramBackup\robot\venv\lib\site-packages\roboticstoolbox\__init__.py:1
# ----> 1 from roboticstoolbox.tools import *
#       3 from roboticstoolbox.robot import *
#       5 from roboticstoolbox.mobile import *
#
# File e:\ProgramBackup\robot\venv\lib\site-packages\roboticstoolbox\tools\__init__.py:2
#       1 from roboticstoolbox.tools.null import null
# ----> 2 from roboticstoolbox.tools.p_servo import p_servo, angle_axis, angle_axis_python
#       3 from roboticstoolbox.tools.Ticker import Ticker
#       4 from roboticstoolbox.tools.urdf import *  # noqa
#
# File e:\ProgramBackup\robot\venv\lib\site-packages\roboticstoolbox\tools\p_servo.py:4
#       1 #!/usr/bin/env python
# ...

# %%
import sys
import time
sys.path.append('E:/ProgramBackup/robot/daran')
import gripper
import DrEmpower_can as dr
import arm_robot as robot
l_p = 0  # 工具参考点到电机输出轴表面的距离，单位mm（所有尺寸参数皆为mm）
l_p_mass_center = 0  # 工具（负载）质心到 6 号关节输出面的距离
G_p = 0  # 负载重量，单位kg，所有重量单位皆为kg
uart_baudrate = 115200  # 串口波特率，与CAN模块的串口波特率一致，（出厂默认为 115200，最高460800）
com = 'COM5'  # 在这里输入 COM 端口号
ro = robot.arm_robot(L_p=l_p, L_p_mass_center=l_p_mass_center, G_p=G_p, com=com, uart_baudrate=uart_baudrate)

# %%
DFbot = DHRobot(
    [
                    RevoluteDH(alpha=np.pi/2,qlim=np.array([-np.pi,np.pi])),
                    RevoluteDH(a=0.15,qlim=np.array([-np.pi,np.pi])),
                    RevoluteDH(a=0.15,qlim=np.array([-np.pi,np.pi])),
                    RevoluteDH(d=-0.05494,alpha=np.pi/2,offset=np.pi/2,qlim=np.array([-np.pi,np.pi])),
                    RevoluteDH(d=0.068,alpha=-np.pi/2,qlim=np.array([-np.pi,3/2*np.pi])),  
                    RevoluteDH(d=0.033,qlim=np.array([-np.pi,3/2*np.pi]))

 
    ],
    name="DFbot",
)

# %%
DFbot.plot([0,0,0,0,0,0])
# Out:
# PyPlot3D backend, t = 0.05, scene:
#   robot: Text(0.0, 0.0, 'DFbot')

# %%
state0=[0,0,0,0,0,0]

# %%
state0_deg=[x/np.pi*180 for x in state0]

# %%
state0_deg
# Out:
# [90.0, -0.0, 90.0, 180.0, 90.0]

# %%
#修改为实验用操控机械臂各关节角到state0位置的代码,速度2
Arm = Arm_Device()
time.sleep(1)
d_claw=0
Arm.Arm_serial_servo_write6(state0_deg[0],state0_deg[1],state0_deg[2],state0_deg[3],state0_deg[4],d_claw, 1500)
time.sleep(0.1)

# %%
state1=[0,-np.pi/3,0,np.pi,0]

# %%
DFbot.plot(state1)
# Out:
# PyPlot3D backend, t = 0.05, scene:
#   robot: Text(0.0, 0.0, 'DFbot')

# %%
T1=DFbot.fkine(state1)

# %%
T1
# Out:
#   -0.5       0        -0.866    -0.1781
#    0         1         0         0
#    0.866     0        -0.5       0.13
#    0         0         0         1

# %%
state1_deg=[x/np.pi*180 for x in state1]

# %%
#修改为实验用操控机械臂各关节角运动到state1位置的代码，速度2
Arm = Arm_Device()
time.sleep(1)
d_claw=0
Arm.Arm_serial_servo_write6(state1_deg[0],state1_deg[1],state1_deg[2],state1_deg[3],state1_deg[4],d_claw, 1500)
time.sleep(1)

# %%
T2=np.array(T1)
T2[0,-1]=-0.255
T2[2,-1]=0.02

# %%
sol = DFbot.ikine_LM(T2,q0=[0,0,0,0,0],ilimit=100, slimit=100,joint_limits=True)

# %%
sol
# Out:
# IKSolution(q=array([ 0.        , -0.38115342,  0.3482598 ,  2.12728867,  0.        ]), success=True, iterations=8, searches=1, residual=1.7092975388849101e-07, reason='Success')

# %%
DFbot.plot(sol.q)
# Out:
# PyPlot3D backend, t = 0.05, scene:
#   robot: Text(0.0, 0.0, 'DFbot')

# %%
state2=sol.q

# %%
state2_deg=[x/np.pi*180 for x in state2]

# %%
#修改为实验用操控机械臂运动末端到指定的x\y\z（state2）位置的代码，速度2
Arm = Arm_Device()
time.sleep(1)
d_claw=0
Arm.Arm_serial_servo_write6(state2_deg[0],state2_deg[1],state2_deg[2],state2_deg[3],state2_deg[4],d_claw, 1500)
time.sleep(1)
